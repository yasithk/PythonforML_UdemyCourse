# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('DATA/kc_house_data.csv')

# %%
## check for missing data
#### count for NULL values per variable
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %% [markdown]
# ### Exploratory data analysis

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %% [markdown]
# ###### most of houses vary between 0 - 2000,000 We could drop the houses more than 2m

# %%
sns.countplot(df['bedrooms'])

# %% [markdown]
# ### Explore highlighly correlated variables

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,9))
plt.scatter(x='price', y='sqft_living', data= df)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='price', y = 'long', data =df)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='price', y = 'lat', data =df)

# %%
### a combination of lattitude and longitude seems to have affect on the housing prices. Indicating an expenesive area of the county.

# %%
plt.figure(figsize=(11,11))
sns.scatterplot(x='long', y='lat', data=df, hue='price')
#plt.scatter(x='long', y= 'lat', data =df, c = df['price'])

# %%
df.sort_values('price', ascending=False)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
## only around 15-20 houses above $3m

# %%
#grab the bottom 99% of the houses to filter the expensive outlier houses
non_top_1_perc = df.sort_values('price', ascending=False).iloc[216:]

# %%
non_top_1_perc.head()
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 6329       8510     2.0           0     1     ...         10        3610
# 12271     23373     3.0           0     1     ...         11        5050
# 9166      12566     1.0           1     4     ...          8        1940
# 12565     31353     2.0           0     0     ...         12        4430
# 1150       7898     1.0           1     4     ...          8        1560
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
plt.figure(figsize=(11,11))
sns.scatterplot(x='long', y='lat', data=non_top_1_perc, 
                edgecolor=None, alpha=0.2, palette='RdYlGn',
                hue='price')

# %% [markdown]
# ##### This gives better information we had before about housing prices and their geographical location.
# Edge of the water we see some lighter points.

# %%
sns.boxplot(x='waterfront', y='price', data=df)

# %% [markdown]
# ## Feature engineering

# %%
## drop ID variable
df = df.drop('id', axis =1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-561819b9ce1e> in <module>()
#       1 ## drop ID variable
# ----> 2 df = df.drop('id', axis =1)
#
# C:\Users\yasit\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\Users\yasit\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
# ...

# %%
## Convert datetime variable. Convert a string into a datetime object
df['date'] = pd.to_datetime(df['date'])
df['date'].head()
# Out:
# 0   2014-10-13
# 1   2014-12-09
# 2   2015-02-25
# 3   2014-12-09
# 4   2015-02-18
# Name: date, dtype: datetime64[ns]

# %%
## grab the year, month of the date
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...    sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...                0      1955             0
# 1           0     0          3  ...              400      1951          1991
# 2           0     0          3  ...                0      1933             0
# 3           0     0          5  ...              910      1965             0
# 4           0     0          3  ...                0      1987             0
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='month', y='price', data =df)

# %%
df.groupby('month').mean()['price'].plot()

# %%
df.groupby('year').mean()['price'].plot()

# %%
df = df.drop('date', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-e55e2dc5d907> in <module>()
# ----> 1 df = df.drop('date', axis = 1)
#
# C:\Users\yasit\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\Users\yasit\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...    sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...                0      1955             0
# 1     0          3      7  ...              400      1951          1991
# 2     0          3      6  ...                0      1933             0
# 3     0          5      7  ...              910      1965             0
# 4     0          3      8  ...                0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
## is there a continous relationship between zipcodes and long/lat? or should it be kept as a categorical
## 70 categories is too much, therefore we'll drop it
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
# 98042    547
# 98034    545
# 98118    507
# 98023    499
# 98006    498
# 98133    493
# 98059    468
# 98058    455
# 98155    446
# 98074    441
# 98033    432
# 98027    412
# 98125    409
# 98056    406
# 98053    403
# 98001    361
# 98075    359
# 98126    354
# 98092    351
# 98144    343
# 98106    335
# 98116    330
# 98029    321
# 98199    317
# 98004    317
#         ...
# 98112    269
# 98168    269
# 98055    268
# 98107    266
# 98136    263
# 98178    262
# 98030    256
# 98177    255
# 98166    254
# 98022    233
# 98105    229
# 98045    220
# 98002    199
# 98077    198
# 98011    195
# 98019    190
# 98108    186
# 98119    184
# 98005    168
# 98007    141
# 98188    136
# 98032    125
# 98014    124
# 98070    117
# 98109    109
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode', axis =1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-a737b84aadfe> in <module>()
# ----> 1 df = df.drop('zipcode', axis =1)
#
# C:\Users\yasit\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\Users\yasit\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
df['yr_renovated'].value_counts().head(20)
### it may make more sense to create indicator for renovated with higher weighting for more recent renovations
## the more recent the higher the value
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
# 2007       35
# 2005       35
# 2004       26
# 1990       25
# 2006       24
# 2009       22
# 1989       22
# 2002       22
# 1991       20
# 2001       19
# 1998       19
# 1994       19
# 1993       19
# 1987       18
# 1983       18
# Name: yr_renovated, dtype: int64
